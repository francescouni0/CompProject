# %%
import reading
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dense, Flatten, InputLayer, Activation, Dropout
from tensorflow.keras.layers import Conv2D, Conv3D, AveragePooling2D, AveragePooling3D, MaxPooling2D, MaxPooling3D,GlobalAvgPool2D
from tensorflow.keras.optimizers import Adam, SGD
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import roc_curve, auc
import os
from tensorflow.keras import layers

# %% [markdown]
# Import dataset

# %%
paths_FA= reading.data_path("Diffusion_parameters_maps-20230215T134959Z-001","corrected_FA_image")

paths_FA.sort(key=lambda x: int(os.path.basename(x).split('_')[3]))

dataset=pd.DataFrame(pd.read_csv('ADNI_dataset_diffusion.csv'))
dataset.sort_values(by=["Subject"],inplace=True)
dataset["Path"]=paths_FA
pd.set_option("max_colwidth",None)

dataset.head()
# Out:
#     Subject  Group Sex   Age  \
# 67     4002      0   F  74.0
# 68     4003      0   F  72.0
# 28     4009      1   M  90.0
# 69     4018      0   M  76.0
# 70     4050      0   M  77.0
#
#                                                                                                                                                                                                                    Path
# 67  Diffusion_parameters_maps-20230215T134959Z-001\Diffusion_parameters_maps\098_S_4002\corrected_FA_image\2011-02-28_15_42_50.0\I397180\ADNI_098_S_4002_MR_corrected_FA_image_Br_20131105134057196_S100616_I397180.nii
# 68  Diffusion_parameters_maps-20230215T134959Z-001\Diffusion_parameters_maps\098_S_4003\corrected_FA_image\2011-03-22_09_23_47.0\I299742\ADNI_098_S_4003_MR_corrected_FA_image_Br_20120421215950180_S102157_I299742.nii
# 28  Diffusion_parameters_maps-20230215T134959Z-001\Diffusion_parameters_maps\016_S_4009\corrected_FA_image\2011-06-18_12_22_12.0\I299644\ADNI_016_S_4009_MR_corrected_FA_image_Br_20120421205831338_S112088_I299644.nii
# 69  Diffusion_parameters_maps-20230215T134959Z-001\Diffusion_parameters_maps\098_S_4018\corrected_FA_image\2011-04-22_15_36_10.0\I299744\ADNI_098_S_4018_MR_corrected_FA_image_Br_20120421220032350_S105027_I299744.nii
# 70  Diffusion_parameters_maps-20230215T134959Z-001\Diffusion_parameters_maps\098_S_4050\corrected_FA_image\2011-05-27_15_33_58.0\I299745\ADNI_098_S_4050_MR_corrected_FA_image_Br_20120421220057813_S110467_I299745.nii

# %%
images_list = []
for i, datapath in enumerate(dataset["Path"]):
    image = np.asarray(nib.load(datapath).get_fdata())
    #image[image == 0] = float('NaN')
    images_list.append(image)
    
images = np.array(images_list, dtype='float64')
labels = np.array(dataset["Group"], dtype='int64')

# %% [markdown]
# Data augmentation

# %%
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

data_augmentation1 = Sequential([layers.RandomFlip(mode='horizontal_and_vertical')])

data_augmentation2 = Sequential([layers.RandomRotation((-0.5,0.5))])

data_augmentation3 = Sequential([layers.RandomZoom(0.5)])

# %%
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

imagesau2=data_augmentation2(images)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

imagesau3=data_augmentation3(images)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
images1=np.append(images,imagesau2,axis=0)
#images2=np.append(images1,imagesau2,axis=0)

# %%
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

images=np.append(images1,imagesau3,axis=0)

print(np.shape(images))
# Out:
# (291, 110, 110, 110)

# %%
labels1=np.append(labels,labels)
#labels2=np.append(labels1,labels)

labels=np.append(labels1,labels)

print(np.shape(labels))
# Out:
# (291,)

# %%
def split_2D():
    X_train, x_test, Y_train, y_test = train_test_split(images[:,:,:,53:56], labels, test_size=0.2, random_state=10)
    x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.25, random_state=20)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
x_train, y_train, x_val, y_val, x_test, y_test = split_2D()
print(x_train.shape)
# Out:
# (174, 110, 110, 3)

# %%
def make_2D_CNN_best1(shape=(110, 110, 3)):
  model = Sequential([
      
      Conv2D(2, (5,5), padding='valid', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),
      
      MaxPooling2D((2,2), strides=2),
      #Dropout(0.4),
      
      Conv2D(4, (5,5), padding='valid', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((3,3), strides=2),
      #Dropout(0.4),False
      
      Conv2D(8, (5,5), padding='valid', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((4,4), strides=2),
      #Dropout(0.4),
      
      Conv2D(16, (5,5), padding='valid', input_shape=shape),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((5,5), strides=2),
      #Dropout(0.4),False

      Flatten(),

      Dense(20, activation='relu'),
      #Dropout(0.1),
      Dense(1, activation='sigmoid')
     
  ])
  return model

# %%
def make_2D_CNN_best2(shape=(110, 110, 3)):
  model = Sequential([
      
      Conv2D(2, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),
      
      MaxPooling2D((2,2), strides=2),
      #Dropout(0.4),
      
      Conv2D(4, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((3,3), strides=2),
      #Dropout(0.4),
      
      Conv2D(8, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((4,4), strides=2),
      #Dropout(0.4),
      
      Conv2D(16, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((5,5), strides=2),
      #Dropout(0.4),

      Flatten(),

      Dense(20, activation='relu'),
      #Dropout(0.1),
      Dense(1, activation='sigmoid')
     
  ])
  return model

# %%
def make_2D_CNN_best3(shape=(110, 110, 3)):
  model = Sequential([
      
      Conv2D(4, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),
      
      MaxPooling2D((2,2), strides=2),
      #Dropout(0.4),
      
      Conv2D(8, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((3,3), strides=3),
      #Dropout(0.4),
      
      Conv2D(16, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((4,4), strides=2),
      #Dropout(0.4),

      Flatten(),

      Dense(20, activation='relu'),
      #Dropout(0.1),
      Dense(1, activation='sigmoid')
     
  ])
  return model

# %%
def make_2D_CNN(shape=(110, 110, 3)):
  model = Sequential([
      
      Conv2D(4, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),
      
      MaxPooling2D((2,2), strides=2),
      #Dropout(0.4),
      
      Conv2D(8, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((3,3), strides=3),
      #Dropout(0.4),
      
      Conv2D(16, (5,5), padding='valid', input_shape=shape,kernel_regularizer='l2'),
      BatchNormalization(),
      Activation('relu'),

      MaxPooling2D((4,4), strides=2),
      #Dropout(0.4),

      Flatten(),

      Dense(25, activation='relu'),
      #Dropout(0.1),
      Dense(1, activation='sigmoid')
     
  ])
  return model

# %%
model = make_2D_CNN()
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 106, 106, 4)       304
#
#  batch_normalization_9 (Batc  (None, 106, 106, 4)      16
#  hNormalization)
#
#  activation_9 (Activation)   (None, 106, 106, 4)       0
#
#  max_pooling2d_9 (MaxPooling  (None, 53, 53, 4)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 49, 49, 8)         808
#
#  batch_normalization_10 (Bat  (None, 49, 49, 8)        32
#  chNormalization)
#
#  activation_10 (Activation)  (None, 49, 49, 8)         0
#
#  max_pooling2d_10 (MaxPoolin  (None, 16, 16, 8)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 16)        3216
#
#  batch_normalization_11 (Bat  (None, 12, 12, 16)       64
#  chNormalization)
#
#  activation_11 (Activation)  (None, 12, 12, 16)        0
#
#  max_pooling2d_11 (MaxPoolin  (None, 5, 5, 16)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 400)               0
#
#  dense_6 (Dense)             (None, 25)                10025
#
#  dense_7 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 14,491
# Trainable params: 14,435
# Non-trainable params: 56
# _________________________________________________________________

# %%
model.compile(optimizer=SGD(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])

# %%
reduce_on_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=10,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0)

early_stopping = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=100,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=10)

# %%
epochs= 1000
batch_size = 20
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    steps_per_epoch = round(len(x_train)/batch_size),
                    verbose=1,
                    validation_data=(x_val, y_val),
                    validation_steps=round(len(x_val)/batch_size),
                    callbacks=[reduce_on_plateau, early_stopping])
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 2s 123ms/step - loss: 1.6972 - accuracy: 0.5402 - val_loss: 0.9612 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 2/1000
# 9/9 [==============================] - 1s 94ms/step - loss: 0.9100 - accuracy: 0.5575 - val_loss: 0.8967 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 3/1000
# 9/9 [==============================] - 1s 115ms/step - loss: 0.8923 - accuracy: 0.5632 - val_loss: 0.8924 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 4/1000
# 9/9 [==============================] - 1s 112ms/step - loss: 0.8743 - accuracy: 0.5632 - val_loss: 0.8918 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 5/1000
# 9/9 [==============================] - 1s 113ms/step - loss: 0.8473 - accuracy: 0.5632 - val_loss: 0.8884 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 6/1000
# 9/9 [==============================] - 1s 111ms/step - loss: 0.8365 - accuracy: 0.5632 - val_loss: 0.8776 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 7/1000
# 9/9 [==============================] - 1s 107ms/step - loss: 0.8365 - accuracy: 0.5632 - val_loss: 0.8685 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 8/1000
# 9/9 [==============================] - 1s 112ms/step - loss: 0.8247 - accuracy: 0.5632 - val_loss: 0.8633 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 9/1000
# 9/9 [==============================] - 1s 108ms/step - loss: 0.8139 - accuracy: 0.5632 - val_loss: 0.8585 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 10/1000
# 9/9 [==============================] - 1s 109ms/step - loss: 0.8059 - accuracy: 0.5632 - val_loss: 0.8515 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 11/1000
# 9/9 [==============================] - 1s 106ms/step - loss: 0.7973 - accuracy: 0.5690 - val_loss: 0.8499 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 12/1000
# 9/9 [==============================] - 1s 104ms/step - loss: 0.7712 - accuracy: 0.6207 - val_loss: 0.8409 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 13/1000
# 9/9 [==============================] - 1s 106ms/step - loss: 0.8141 - accuracy: 0.6092 - val_loss: 0.8315 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 14/1000
# 9/9 [==============================] - 1s 102ms/step - loss: 0.7947 - accuracy: 0.6264 - val_loss: 0.8294 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 15/1000
# 9/9 [==============================] - 1s 104ms/step - loss: 0.7654 - accuracy: 0.6207 - val_loss: 0.8293 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 16/1000
# 9/9 [==============================] - 1s 104ms/step - loss: 0.7707 - accuracy: 0.6149 - val_loss: 0.8214 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 17/1000
# 9/9 [==============================] - 1s 102ms/step - loss: 0.7307 - accuracy: 0.6782 - val_loss: 0.8139 - val_accuracy: 0.4310 - lr: 0.1000
# Epoch 18/1000
# 9/9 [==============================] - 1s 102ms/step - loss: 0.7433 - accuracy: 0.6552 - val_loss: 0.8055 - val_accuracy: 0.5690 - lr: 0.1000
# Epoch
- val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 73/1000
# 9/9 [==============================] - 1s 94ms/step - loss: 0.1403 - accuracy: 0.9943 - val_loss: 1.4391 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 74/1000
# 9/9 [==============================] - 1s 100ms/step - loss: 0.1529 - accuracy: 0.9943 - val_loss: 1.4335 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 75/1000
# 9/9 [==============================] - 1s 100ms/step - loss: 0.1517 - accuracy: 0.9828 - val_loss: 1.4233 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 76/1000
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1400 - accuracy: 0.9885 - val_loss: 1.4118 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 77/1000
# 9/9 [==============================] - 1s 99ms/step - loss: 0.1377 - accuracy: 0.9943 - val_loss: 1.3811 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 78/1000
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1413 - accuracy: 0.9943 - val_loss: 1.3439 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 79/1000
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1381 - accuracy: 0.9943 - val_loss: 1.2952 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 80/1000
# 9/9 [==============================] - 1s 96ms/step - loss: 0.1496 - accuracy: 0.9885 - val_loss: 1.2526 - val_accuracy: 0.5690 - lr: 1.0000e-03
# Epoch 81/1000
# 9/9 [==============================] - 1s 96ms/step - loss: 0.1472 - accuracy: 0.9828 - val_loss: 1.1908 - val_accuracy: 0.5862 - lr: 1.0000e-04
# Epoch 82/1000
# 9/9 [==============================] - 1s 96ms/step - loss: 0.1643 - accuracy: 0.9828 - val_loss: 1.1304 - val_accuracy: 0.6207 - lr: 1.0000e-04
# Epoch 83/1000
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1358 - accuracy: 1.0000 - val_loss: 1.0712 - val_accuracy: 0.6379 - lr: 1.0000e-04
# Epoch 84/1000
# 9/9 [==============================] - 1s 96ms/step - loss: 0.1380 - accuracy: 0.9943 - val_loss: 1.0098 - val_accuracy: 0.6379 - lr: 1.0000e-04
# Epoch 85/1000
# 9/9 [==============================] - 1s 94ms/step - loss: 0.1541 - accuracy: 0.9828 - val_loss: 0.9484 - val_accuracy: 0.6552 - lr: 1.0000e-04
# Epoch 86/1000
# 9/9 [==============================] - 1s 96ms/step - loss: 0.1487 - accuracy: 0.9885 - val_loss: 0.8962 - val_accuracy: 0.6897 - lr: 1.0000e-04
# Epoch 87/1000
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1419 - accuracy: 1.0000 - val_loss: 0.8462 - val_accuracy: 0.7069 - lr: 1.0000e-04
# Epoch 88/1000
# 9/9 [==============================] - 1s 98ms/step - loss: 0.1461 - accuracy: 0.9943 - val_loss: 0.8033 - val_accuracy: 0.7069 - lr: 1.0000e-04

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc)+1)
#Train and validation accuracy 
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#Train and validation loss 
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
_, val_acc = model.evaluate(x_val, y_val, verbose=0)
print('Validation accuracy: %.3f' % (val_acc))

preds = model.predict(x_val, verbose=1)
#Compute Receiver operating characteristic (ROC)
fpr, tpr, _ = roc_curve(y_val, preds)
roc_auc = auc(fpr, tpr)
print('AUC = %.3f'% (roc_auc))

#Plot of a ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Validation ROC')
plt.legend(loc="lower right")
plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy: %.3f' % (test_acc))

preds_test = model.predict(x_test, verbose=1)
fpr, tpr, _ = roc_curve(y_test, preds_test)
roc_auc = auc(fpr, tpr)
print('AUC = %.3f'% (roc_auc))

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test ROC')
plt.legend(loc="lower right")
plt.show()
